# %% [markdown]
# <a href="https://colab.research.google.com/github/sxm18940/Assignment2/blob/main/ML_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Numpy:
#Using NumPy create random vector of size 15 having only Integers in the range 1-20.
#1.a Reshape the array to 3 by 5
import numpy as np
rand_vector = np.random.randint(1,20, size = 15).reshape(3,5)
print (rand_vector)
# Out:
# [[18 17 17 16  8]
#  [ 2  6 10 13  4]
#  [18  8 11  5  4]]

# %%
#1.b Print array shape.
print("Array_Shape: ",rand_vector.shape)
# Out:
# Array_Shape:  (3, 5)

# %%
#1.c Replace the max in each row by 0
Max_val= np.amax(rand_vector, axis = 1)
Max_val= Max_val[:, None]
new_Arr = np.where(rand_vector==Max_val,0,rand_vector)
print(new_Arr)
# Out:
# [[ 0 17 17 16  8]
#  [ 2  6 10  0  4]
#  [ 0  8 11  5  4]]

# %%
#2Read the provided CSV file ‘data.csv’.
#https://drive.google.com/drive/folders/1h8C3mLsso-R-sIOLsvoYwPLzy2fJ4IOF?usp=sharing
import pandas as pd
import pandas
from google.colab import drive
drive.mount('/content/gdrive')
data_frame=pd.read_csv("gdrive/My Drive/m/data.csv")
data_frame.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
#Show the basic statistical description about the data.
data_frame.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
#Check if the data has null values.
#a. Replace the null values with the mean
data_frame.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
mean_calories=df['Calories'].mean()
data_frame['Calories'].fillna(value=mean_calories,inplace=True)
data_frame.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
#Select at least two columns and aggregate the data using: min, max, count, mean
data_frame.Duration.describe()
# Out:
# count    169.000000
# mean      63.846154
# std       42.299949
# min       15.000000
# 25%       45.000000
# 50%       60.000000
# 75%       60.000000
# max      300.000000
# Name: Duration, dtype: float64

# %%
data_frame.Pulse.describe()
# Out:
# count    169.000000
# mean     107.461538
# std       14.510259
# min       80.000000
# 25%      100.000000
# 50%      105.000000
# 75%      111.000000
# max      159.000000
# Name: Pulse, dtype: float64

# %%
#Filter the dataframe to select the rows with calories values between 500 and 1000. 
data_frame[(data_frame['Calories']>500) & (data_frame['Calories']<1000)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
#Filter the dataframe to select the rows with calories values > 500 and pulse < 100. 
data_frame[(data_frame['Calories']>500) & (data_frame['Pulse']<100)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
#Create a new “df_modified” dataframe that contains all the columns from df except for “Maxpulse”.
data_frame_modified=data_frame.drop("Maxpulse",axis=1)
data_frame_modified
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
#Delete the “Maxpulse” column from the main df dataframe
data_frame=data_frame.drop("Maxpulse",axis=1)
data_frame
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
#Convert the datatype of Calories column to int datatype.
data_frame['Calories']=data_frame['Calories'].astype(int)
data_frame.dtypes
# Out:
# Duration    int64
# Pulse       int64
# Calories    int64
# dtype: object

# %%
#Using pandas create a scatter plot for the two columns (Duration and Calories).
data_frame.plot.scatter(x='Duration',y='Calories')

# %%
from matplotlib import pyplot as plot
#Given data to plot
lang = lang = 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ['#1f77b4','#ff7f0e','#2ca02c','#d62728','#9467bd','#8c564b']
myexplode = [0.09,0,0,0,0,0]
plot.pie(popularity,labels=lang,colors=colors,explode=myexplode,shadow=True,startangle=140,
       wedgeprops = {'edgecolor':'white'},autopct='%1.1f%%')
plot.tight_layout()
plot.show()
